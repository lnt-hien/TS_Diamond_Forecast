# %% [markdown]
# # Diamond forecasting

# %%
## install darts
## https://github.com/unit8co/darts/blob/master/INSTALL.md

## Example
## https://unit8co.github.io/darts/examples/07-NBEATS-examples.html

## Download price data
## !gdown 1Hn4B_QaZWUQE1fPdhBUtlexe0MVVLfjE


## Nbeats
## https://unit8co.github.io/darts/generated_api/darts.models.forecasting.nbeats.html

## NHiTs
## https://unit8co.github.io/darts/generated_api/darts.models.forecasting.nhits.html

## NLinear
## https://unit8co.github.io/darts/generated_api/darts.models.forecasting.nlinear.html

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt



from darts import TimeSeries
from darts.models import NBEATSModel
from darts.models import NHiTSModel
from darts.models import NLinearModel
from darts.models import DLinearModel


from darts.dataprocessing.transformers import Scaler, MissingValuesFiller
from darts.metrics import mape, r2_score
from darts.metrics import mae
from darts.datasets import EnergyDataset

# %%
df = pd.read_csv('df_diamond.csv',index_col=[0])[::-1]
df.reset_index(inplace=True, drop=True)
df.date = pd.to_datetime(df.date)
df.set_index('date',inplace=True)
df
# Out:
#             diamond price  inflation rate  interest rate  fed rate  gold price
# date
# 2018-04-28       10030.58             NaN            NaN      1.70         NaN
# 2018-04-29       10032.95             NaN            NaN      1.70     1322.80
# 2018-04-30       10038.62            2.17           0.78      1.69     1315.38
# 2018-05-01       10050.07            2.16           0.81      1.70     1300.58
# 2018-05-02       10047.16            2.17           0.80      1.70     1302.13
# ...                   ...             ...            ...       ...         ...
# 2021-05-31       10368.67             NaN            NaN      0.05     1905.74
# 2021-06-01       10376.10            2.46          -0.84      0.06     1900.49
# 2021-06-02       10378.43            2.44          -0.85      0.06     1907.75
# 2021-06-03       10385.16            2.42          -0.79      0.06     1871.36
# 2021-06-04       10385.16            2.40          -0.84      0.06     1890.97
#
# ...

# %%
def display_forecast(pred_series, ts_transformed, forecast_type, start_date=None):
    plt.figure(figsize=(8, 5))
    if start_date:
        ts_transformed = ts_transformed.drop_before(start_date)
    ts_transformed.univariate_component(0).plot(label="actual")
    pred_series.plot(label=("historic " + forecast_type + " forecasts"))
    plt.title(
        "R2: {}".format(r2_score(ts_transformed.univariate_component(0), pred_series))
    )
    plt.legend()

# %%
df_day_avg = df.groupby(df.index.astype(str).str.split(" ").str[0]).mean().reset_index()
filler = MissingValuesFiller()
scaler = Scaler()
series = scaler.fit_transform(
    filler.transform(
        TimeSeries.from_dataframe(
            df_day_avg, "date", ["diamond price"]
        )
    )
).astype(np.float32)

series.plot()
plt.title("diamond price")
# Out:
# Text(0.5, 1.0, 'diamond price')

# %% [markdown]
# ## NBEATS

# %%
train, val = series.split_after(pd.Timestamp("20200101"))

# %%
nbeats_gen = NBEATSModel(
    input_chunk_length=30,
    output_chunk_length=7,
    generic_architecture=True,
    num_blocks=3,
    num_layers=4,
    layer_widths=512,
    n_epochs=100,
    nr_epochs_val_period=1,
    batch_size=500,
    model_name="nbeats_generic_run",
)
nbeats_gen.to_cpu()

nbeats_int = NBEATSModel(
    input_chunk_length=30,
    output_chunk_length=7,
    generic_architecture=False,
    num_blocks=3,
    num_layers=4,
    layer_widths=512,
    n_epochs=100,
    nr_epochs_val_period=1,
    batch_size=500,
    model_name="nbeats_interpretable_run",
)

nhits = NHiTSModel(
    input_chunk_length=30, 
    output_chunk_length=7,
    n_epochs=100,
    nr_epochs_val_period=1,
    batch_size=500,
    model_name="nbeats_interpretable_run",)

nhits.to_cpu()

nlinear = NLinearModel(
    input_chunk_length=30, 
    output_chunk_length=7,
    n_epochs=100,
    nr_epochs_val_period=1,
    batch_size=500,)

dlinear = DLinearModel(
    input_chunk_length=30, 
    output_chunk_length=7,
    n_epochs=100,
    nr_epochs_val_period=1,
    batch_size=500,)

# %%
nbeats_gen.fit(series=train, val_series=val, verbose=True)
nbeats_int.fit(series=train, val_series=val, verbose=True)
nhits.fit(train,val_series=val, verbose=True)
nlinear.fit(train,val_series=val, verbose=True)
dlinear.fit(train,val_series=val, verbose=True)
# Out:
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /Users/quochungha/miniconda3/envs/ts/lib/python3.9/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
#
#   | Name          | Type             | Params
# ---------------------------------------------------
# 0 | criterion     | MSELoss          | 0
# 1 | train_metrics | MetricCollection | 0
# 2 | val_metrics   | MetricCollection | 0
# 3 | stacks        | ModuleList       | 72.8 M
# ---------------------------------------------------
# 72.8 M    Trainable params
# 2.7 K     Non-trainable params
# 72.8 M    Total params
# 291.309   Total estimated model params size (MB)
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# ...

# %%
nbeats_ge_pred_series = nbeats_gen.historical_forecasts(
    series,
    start=pd.Timestamp("20200101"),
    forecast_horizon=7,
    stride=5,
    retrain=False,
    verbose=True,
)

nbeats_int_pred_series = nbeats_int.historical_forecasts(
    series,
    start=pd.Timestamp("20200101"),
    forecast_horizon=7,
    stride=5,
    retrain=False,
    verbose=True,
)

nhits_pred_series = nhits.historical_forecasts(
    series,
    start=pd.Timestamp("20200101"),
    forecast_horizon=7,
    stride=5,
    retrain=False,
    verbose=True,
)
nlinear_pred_series = nlinear.historical_forecasts(
    series,
    start=pd.Timestamp("20200101"),
    forecast_horizon=7,
    stride=5,
    retrain=False,
    verbose=True,
)
dlinear_pred_series = dlinear.historical_forecasts(
    series,
    start=pd.Timestamp("20200101"),
    forecast_horizon=7,
    stride=5,
    retrain=False,
    verbose=True,
)
# Out:
#   0%|          | 0/103 [00:00<?, ?it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /Users/quochungha/miniconda3/envs/ts/lib/python3.9/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting: 0it [00:00, ?it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# Predicting: 0it [00:00, ?it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# Predicting: 0it [00:00, ?it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# ...

# %%
nbeats_gen.save('model/nbeats_generic.pt')
nbeats_int.save('model/nbeats_intepret.pt')
nhits.save('model/nhits.pt')
nlinear.save('model/nlinear.pt')
dlinear.save('model/dlinear.pt')

# %%
display_forecast(nbeats_ge_pred_series, series, "7 day", start_date=pd.Timestamp("20200101"))
display_forecast(nbeats_int_pred_series, series, "7 day", start_date=pd.Timestamp("20200101"))
display_forecast(nhits_pred_series, series, "7 day", start_date=pd.Timestamp("20200101"))
display_forecast(nlinear_pred_series, series, "7 day", start_date=pd.Timestamp("20200101"))
display_forecast(dlinear_pred_series, series, "7 day", start_date=pd.Timestamp("20200101"))

# %% [markdown]
# ## Easier period

# %%
train1, val1 = series.split_after(pd.Timestamp("20210101"))

# %%
nbeats_gen.fit(series=train1, val_series=val1, verbose=True)
nbeats_int.fit(series=train1, val_series=val1, verbose=True)
nhits.fit(train1,val_series=val1, verbose=True)
nlinear.fit(train1,val_series=val1, verbose=True)
dlinear.fit(train1,val_series=val1, verbose=True)
# Out:
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /Users/quochungha/miniconda3/envs/ts/lib/python3.9/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
#
#   | Name          | Type             | Params
# ---------------------------------------------------
# 0 | criterion     | MSELoss          | 0
# 1 | train_metrics | MetricCollection | 0
# 2 | val_metrics   | MetricCollection | 0
# 3 | stacks        | ModuleList       | 72.8 M
# ---------------------------------------------------
# 72.8 M    Trainable params
# 2.7 K     Non-trainable params
# 72.8 M    Total params
# 291.309   Total estimated model params size (MB)
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# ...

# %%
nbeats_ge_pred_series = nbeats_gen.historical_forecasts(
    series,
    start=pd.Timestamp("20210101"),
    forecast_horizon=7,
    stride=5,
    retrain=False,
    verbose=True,
)
nbeats_int_pred_series = nbeats_int.historical_forecasts(
    series,
    start=pd.Timestamp("20210101"),
    forecast_horizon=7,
    stride=5,
    retrain=False,
    verbose=True,
)

nhits_pred_series = nhits.historical_forecasts(
    series,
    start=pd.Timestamp("20210101"),
    forecast_horizon=7,
    stride=5,
    retrain=False,
    verbose=True,
)
nlinear_pred_series = nlinear.historical_forecasts(
    series,
    start=pd.Timestamp("20210101"),
    forecast_horizon=7,
    stride=5,
    retrain=False,
    verbose=True,
)
dlinear_pred_series = dlinear.historical_forecasts(
    series,
    start=pd.Timestamp("20210101"),
    forecast_horizon=7,
    stride=5,
    retrain=False,
    verbose=True,
)
# Out:
#   0%|          | 0/30 [00:00<?, ?it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /Users/quochungha/miniconda3/envs/ts/lib/python3.9/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Predicting: 0it [00:00, ?it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# Predicting: 0it [00:00, ?it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# Predicting: 0it [00:00, ?it/s]
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# ...

# %%
display_forecast(nbeats_ge_pred_series, series, "7 day", start_date=pd.Timestamp("20210101"))
display_forecast(nbeats_int_pred_series, series, "7 day", start_date=pd.Timestamp("20210101"))
display_forecast(nhits_pred_series, series, "7 day", start_date=pd.Timestamp("20210101"))
display_forecast(nlinear_pred_series, series, "7 day", start_date=pd.Timestamp("20210101"))
display_forecast(dlinear_pred_series, series, "7 day", start_date=pd.Timestamp("20210101"))
